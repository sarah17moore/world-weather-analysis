# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 781

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Assemble the OpenWeatherMap's API call
    url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san vicente
# Processing Record 2 of Set 1 | astoria
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | puerto ayacucho
# Processing Record 5 of Set 1 | imeni poliny osipenko
# Processing Record 6 of Set 1 | kulhudhuffushi
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | svetlaya
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | cervo
# Processing Record 12 of Set 1 | arawa
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | kruisfontein
# Processing Record 15 of Set 1 | turkistan
# Processing Record 16 of Set 1 | farmington
# Processing Record 17 of Set 1 | cabedelo
# Processing Record 18 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | bykovo
# Processing Record 22 of Set 1 | mao
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | birao
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | marang
# Processing Record 29 of Set 1 | labis
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | sangar
# Processing Record 33 of Set 1 | makakilo city
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | uniao
# Processing Record 37 of Set 1 | mandalgovi
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | palmer
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | manzanillo
# Processing Record 42 of Set 1 | bubaque
# Processing Record 43 of Set 1 | huai yot
# Processing Record 44 of Set 1 | strezhevoy
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | oistins
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | rabo de peixe
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | lorengau
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | chambar
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | fukue
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | de-kastri
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | vanimo
# Processing Record 16 of Set 2 | kincardine
# Processing Record 17 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 2 | oranjemund
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | gamba
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | east grinstead
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | san pedro buenavista
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | jumla
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | majene
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | jardim
# Processing Record 37 of Set 2 | korem
# Processing Record 38 of Set 2 | miles city
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | gazimurskiy zavod
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | bouafle
# Processing Record 44 of Set 2 | porto walter
# Processing Record 45 of Set 2 | beloha
# Processing Record 46 of Set 2 | chikoy
# City not found. Skipping...
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | mayo
# Processing Record 50 of Set 2 | maldonado
# Processing Record 1 of Set 3 | yarmouth
# Processing Record 2 of Set 3 | ketchikan
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | lompoc
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | iralaya
# Processing Record 7 of Set 3 | gizo
# Processing Record 8 of Set 3 | half moon bay
# Processing Record 9 of Set 3 | svetlogorsk
# Processing Record 10 of Set 3 | leh
# Processing Record 11 of Set 3 | samarai
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | jasper
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | bayeux
# Processing Record 18 of Set 3 | ambilobe
# Processing Record 19 of Set 3 | korcula
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | nybro
# Processing Record 22 of Set 3 | kemin
# Processing Record 23 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | baturaja
# Processing Record 26 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 3 | mango
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | cayenne
# Processing Record 30 of Set 3 | surt
# Processing Record 31 of Set 3 | te anau
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | mount gambier
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | souillac
# Processing Record 36 of Set 3 | presidente dutra
# Processing Record 37 of Set 3 | saint-denis
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | ostrovnoy
# Processing Record 40 of Set 3 | yugorsk
# Processing Record 41 of Set 3 | anamur
# Processing Record 42 of Set 3 | inhambane
# Processing Record 43 of Set 3 | gerash
# Processing Record 44 of Set 3 | katsuura
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | vestmanna
# Processing Record 48 of Set 3 | tautira
# Processing Record 49 of Set 3 | belyy yar
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | ginda
# Processing Record 2 of Set 4 | bonthe
# Processing Record 3 of Set 4 | vila franca do campo
# Processing Record 4 of Set 4 | hobart
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | tasiilaq
# Processing Record 8 of Set 4 | tarut
# Processing Record 9 of Set 4 | husum
# Processing Record 10 of Set 4 | edson
# Processing Record 11 of Set 4 | bandarbeyla
# Processing Record 12 of Set 4 | galle
# Processing Record 13 of Set 4 | bac lieu
# Processing Record 14 of Set 4 | torata
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | westport
# Processing Record 18 of Set 4 | fort smith
# Processing Record 19 of Set 4 | saint-joseph
# Processing Record 20 of Set 4 | grand gaube
# Processing Record 21 of Set 4 | zhigansk
# Processing Record 22 of Set 4 | huancavelica
# Processing Record 23 of Set 4 | kiruna
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | kibaha
# Processing Record 27 of Set 4 | laguna
# Processing Record 28 of Set 4 | arequipa
# Processing Record 29 of Set 4 | barra do garcas
# Processing Record 30 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 4 | serenje
# Processing Record 32 of Set 4 | kati
# Processing Record 33 of Set 4 | pangnirtung
# Processing Record 34 of Set 4 | cuprija
# Processing Record 35 of Set 4 | gweta
# Processing Record 36 of Set 4 | yamandu
# Processing Record 37 of Set 4 | gazli
# Processing Record 38 of Set 4 | thompson
# Processing Record 39 of Set 4 | camacha
# Processing Record 40 of Set 4 | berlevag
# Processing Record 41 of Set 4 | pereira barreto
# Processing Record 42 of Set 4 | portland
# Processing Record 43 of Set 4 | roald
# Processing Record 44 of Set 4 | coihaique
# Processing Record 45 of Set 4 | emerald
# Processing Record 46 of Set 4 | almazar
# Processing Record 47 of Set 4 | dunmore town
# Processing Record 48 of Set 4 | kipini
# Processing Record 49 of Set 4 | hanna
# Processing Record 50 of Set 4 | sakakah
# Processing Record 1 of Set 5 | isiro
# Processing Record 2 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | derzhavinsk
# Processing Record 5 of Set 5 | kommunisticheskiy
# Processing Record 6 of Set 5 | manicore
# Processing Record 7 of Set 5 | sarangani
# Processing Record 8 of Set 5 | lang son
# Processing Record 9 of Set 5 | sioux lookout
# Processing Record 10 of Set 5 | college
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | sylva
# Processing Record 13 of Set 5 | zyryanka
# Processing Record 14 of Set 5 | qianan
# Processing Record 15 of Set 5 | saskylakh
# Processing Record 16 of Set 5 | marienburg
# Processing Record 17 of Set 5 | berwyn
# Processing Record 18 of Set 5 | ayer itam
# City not found. Skipping...
# Processing Record 19 of Set 5 | cartagena
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | opuwo
# Processing Record 23 of Set 5 | bayan
# Processing Record 24 of Set 5 | mancheral
# Processing Record 25 of Set 5 | el tarra
# Processing Record 26 of Set 5 | bilma
# Processing Record 27 of Set 5 | yokote
# Processing Record 28 of Set 5 | skjervoy
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | sao joao da barra
# Processing Record 33 of Set 5 | bulgan
# Processing Record 34 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 5 | gigmoto
# Processing Record 36 of Set 5 | lagoa
# Processing Record 37 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 5 | hudiksvall
# Processing Record 39 of Set 5 | itapora
# Processing Record 40 of Set 5 | la ronge
# Processing Record 41 of Set 5 | uchiza
# Processing Record 42 of Set 5 | edemissen
# Processing Record 43 of Set 5 | coahuayana
# Processing Record 44 of Set 5 | mineiros
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | maragogi
# Processing Record 47 of Set 5 | abu kamal
# Processing Record 48 of Set 5 | soyo
# Processing Record 49 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 50 of Set 5 | mitsamiouli
# Processing Record 1 of Set 6 | abinsk
# Processing Record 2 of Set 6 | kaeo
# Processing Record 3 of Set 6 | adrar
# Processing Record 4 of Set 6 | road town
# Processing Record 5 of Set 6 | sibolga
# Processing Record 6 of Set 6 | inza
# Processing Record 7 of Set 6 | maturin
# Processing Record 8 of Set 6 | broome
# Processing Record 9 of Set 6 | sao francisco
# Processing Record 10 of Set 6 | potsdam
# Processing Record 11 of Set 6 | ouadda
# Processing Record 12 of Set 6 | korla
# Processing Record 13 of Set 6 | abiy adi
# City not found. Skipping...
# Processing Record 14 of Set 6 | werota
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | abha
# Processing Record 17 of Set 6 | janakpur road
# City not found. Skipping...
# Processing Record 18 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 6 | atar
# Processing Record 20 of Set 6 | parrita
# Processing Record 21 of Set 6 | ixtapa
# Processing Record 22 of Set 6 | limeira
# Processing Record 23 of Set 6 | missoula
# Processing Record 24 of Set 6 | lata
# Processing Record 25 of Set 6 | benguela
# Processing Record 26 of Set 6 | aitape
# Processing Record 27 of Set 6 | oussouye
# Processing Record 28 of Set 6 | san angelo
# Processing Record 29 of Set 6 | aswan
# Processing Record 30 of Set 6 | hobyo
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | hirara
# Processing Record 33 of Set 6 | kununurra
# Processing Record 34 of Set 6 | tura
# Processing Record 35 of Set 6 | mezen
# Processing Record 36 of Set 6 | le pont-de-claix
# Processing Record 37 of Set 6 | gimli
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | termoli
# Processing Record 41 of Set 6 | brewster
# Processing Record 42 of Set 6 | otradnoye
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | guerrero negro
# Processing Record 45 of Set 6 | golyshmanovo
# Processing Record 46 of Set 6 | nampula
# Processing Record 47 of Set 6 | wanaka
# Processing Record 48 of Set 6 | tuysarkan
# City not found. Skipping...
# Processing Record 49 of Set 6 | la guacamaya
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | sitka
# Processing Record 2 of Set 7 | qingyuan
# Processing Record 3 of Set 7 | arman
# Processing Record 4 of Set 7 | high level
# Processing Record 5 of Set 7 | mogadishu
# Processing Record 6 of Set 7 | stornoway
# Processing Record 7 of Set 7 | henties bay
# Processing Record 8 of Set 7 | port-gentil
# Processing Record 9 of Set 7 | kirkkonummi
# Processing Record 10 of Set 7 | hirtshals
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | tavares
# Processing Record 13 of Set 7 | shingu
# Processing Record 14 of Set 7 | kedougou
# Processing Record 15 of Set 7 | kieta
# Processing Record 16 of Set 7 | uddevalla
# Processing Record 17 of Set 7 | havoysund
# Processing Record 18 of Set 7 | koumra
# Processing Record 19 of Set 7 | herat
# Processing Record 20 of Set 7 | borogontsy
# Processing Record 21 of Set 7 | izhma
# Processing Record 22 of Set 7 | ust-kuyga
# Processing Record 23 of Set 7 | baykit
# Processing Record 24 of Set 7 | comodoro rivadavia
# Processing Record 25 of Set 7 | barwadih
# Processing Record 26 of Set 7 | sayanskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | port lincoln
# Processing Record 28 of Set 7 | vysokogornyy
# Processing Record 29 of Set 7 | mahebourg
# Processing Record 30 of Set 7 | muros
# Processing Record 31 of Set 7 | kathmandu
# Processing Record 32 of Set 7 | penticton
# Processing Record 33 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 7 | williston
# Processing Record 35 of Set 7 | kataysk
# Processing Record 36 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 37 of Set 7 | yulara
# Processing Record 38 of Set 7 | chapais
# Processing Record 39 of Set 7 | najran
# Processing Record 40 of Set 7 | nguru
# Processing Record 41 of Set 7 | hay river
# Processing Record 42 of Set 7 | traverse city
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | maarianhamina
# Processing Record 45 of Set 7 | port blair
# Processing Record 46 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | kanel
# Processing Record 48 of Set 7 | nuevo casas grandes
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | malanje
# Processing Record 1 of Set 8 | tuy hoa
# Processing Record 2 of Set 8 | sakaiminato
# Processing Record 3 of Set 8 | puerto ayora
# Processing Record 4 of Set 8 | vostok
# Processing Record 5 of Set 8 | cortez
# Processing Record 6 of Set 8 | lepenou
# Processing Record 7 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 8 | cherskiy
# Processing Record 9 of Set 8 | kolokani
# Processing Record 10 of Set 8 | axim
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | birnin kebbi
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | elat
# Processing Record 17 of Set 8 | nizhneangarsk
# Processing Record 18 of Set 8 | san andres
# Processing Record 19 of Set 8 | huanren
# Processing Record 20 of Set 8 | ancud
# Processing Record 21 of Set 8 | kodiak
# Processing Record 22 of Set 8 | erzurum
# Processing Record 23 of Set 8 | keetmanshoop
# Processing Record 24 of Set 8 | suez
# Processing Record 25 of Set 8 | lukovetskiy
# Processing Record 26 of Set 8 | rengasdengklok
# Processing Record 27 of Set 8 | lenger
# Processing Record 28 of Set 8 | malpe
# Processing Record 29 of Set 8 | russell
# Processing Record 30 of Set 8 | cabo san lucas
# Processing Record 31 of Set 8 | nizhniy kuranakh
# Processing Record 32 of Set 8 | russkaya polyana
# Processing Record 33 of Set 8 | dalvik
# Processing Record 34 of Set 8 | alyangula
# Processing Record 35 of Set 8 | severo-yeniseyskiy
# Processing Record 36 of Set 8 | hofn
# Processing Record 37 of Set 8 | port macquarie
# Processing Record 38 of Set 8 | slonim
# Processing Record 39 of Set 8 | guamuchil
# Processing Record 40 of Set 8 | puqi
# Processing Record 41 of Set 8 | nyurba
# Processing Record 42 of Set 8 | zhuhai
# Processing Record 43 of Set 8 | manaus
# Processing Record 44 of Set 8 | faanui
# Processing Record 45 of Set 8 | lavrentiya
# Processing Record 46 of Set 8 | sechura
# Processing Record 47 of Set 8 | saint anthony
# Processing Record 48 of Set 8 | lethem
# Processing Record 49 of Set 8 | seydi
# Processing Record 50 of Set 8 | gambela
# Processing Record 1 of Set 9 | namatanai
# Processing Record 2 of Set 9 | dakar
# Processing Record 3 of Set 9 | ilo
# Processing Record 4 of Set 9 | juruti
# Processing Record 5 of Set 9 | udachnyy
# Processing Record 6 of Set 9 | rio gallegos
# Processing Record 7 of Set 9 | amapa
# Processing Record 8 of Set 9 | honiara
# Processing Record 9 of Set 9 | broken hill
# Processing Record 10 of Set 9 | fasa
# Processing Record 11 of Set 9 | kutum
# Processing Record 12 of Set 9 | faya
# Processing Record 13 of Set 9 | atherton
# Processing Record 14 of Set 9 | leonidovo
# Processing Record 15 of Set 9 | alice springs
# Processing Record 16 of Set 9 | puerto narino
# Processing Record 17 of Set 9 | mount pleasant
# Processing Record 18 of Set 9 | nishihara
# Processing Record 19 of Set 9 | akyab
# Processing Record 20 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 9 | buala
# Processing Record 22 of Set 9 | homa bay
# Processing Record 23 of Set 9 | krasnyy chikoy
# Processing Record 24 of Set 9 | klaksvik
# Processing Record 25 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 9 | kirkwood
# Processing Record 28 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 9 | moranbah
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 9 | kuvshinovo
# Processing Record 33 of Set 9 | wake forest
# Processing Record 34 of Set 9 | oparino
# Processing Record 35 of Set 9 | taoudenni
# Processing Record 36 of Set 9 | sao felix do xingu
# Processing Record 37 of Set 9 | bethel
# Processing Record 38 of Set 9 | banda aceh
# Processing Record 39 of Set 9 | necochea
# Processing Record 40 of Set 9 | sorsk
# Processing Record 41 of Set 9 | la sarre
# Processing Record 42 of Set 9 | segezha
# Processing Record 43 of Set 9 | penzance
# Processing Record 44 of Set 9 | padang
# Processing Record 45 of Set 9 | vao
# Processing Record 46 of Set 9 | kungurtug
# Processing Record 47 of Set 9 | upington
# Processing Record 48 of Set 9 | zhanaozen
# Processing Record 49 of Set 9 | kangaatsiaq
# Processing Record 50 of Set 9 | walvis bay
# Processing Record 1 of Set 10 | beringovskiy
# Processing Record 2 of Set 10 | skuodas
# Processing Record 3 of Set 10 | zaragoza
# Processing Record 4 of Set 10 | airai
# Processing Record 5 of Set 10 | luderitz
# Processing Record 6 of Set 10 | coquimbo
# Processing Record 7 of Set 10 | slave lake
# Processing Record 8 of Set 10 | ayan
# Processing Record 9 of Set 10 | bocanda
# Processing Record 10 of Set 10 | pisco
# Processing Record 11 of Set 10 | palm coast
# Processing Record 12 of Set 10 | honningsvag
# Processing Record 13 of Set 10 | haines junction
# Processing Record 14 of Set 10 | plouzane
# Processing Record 15 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 10 | vila velha
# Processing Record 17 of Set 10 | nome
# Processing Record 18 of Set 10 | osypenko
# Processing Record 19 of Set 10 | pudozh
# Processing Record 20 of Set 10 | mountain home
# Processing Record 21 of Set 10 | ponta delgada
# Processing Record 22 of Set 10 | shambu
# Processing Record 23 of Set 10 | zabol
# Processing Record 24 of Set 10 | kahului
# Processing Record 25 of Set 10 | sayalgudi
# City not found. Skipping...
# Processing Record 26 of Set 10 | woodstock
# Processing Record 27 of Set 10 | boditi
# Processing Record 28 of Set 10 | maningrida
# Processing Record 29 of Set 10 | vardo
# Processing Record 30 of Set 10 | merauke
# Processing Record 31 of Set 10 | antofagasta
# Processing Record 32 of Set 10 | burnie
# Processing Record 33 of Set 10 | panama city
# Processing Record 34 of Set 10 | salalah
# Processing Record 35 of Set 10 | usmajac
# Processing Record 36 of Set 10 | neepawa
# Processing Record 37 of Set 10 | anchorage
# Processing Record 38 of Set 10 | havre-saint-pierre
# Processing Record 39 of Set 10 | cockburn town
# Processing Record 40 of Set 10 | san juan
# Processing Record 41 of Set 10 | mayya
# Processing Record 42 of Set 10 | kindu
# Processing Record 43 of Set 10 | bahia blanca
# Processing Record 44 of Set 10 | emba
# Processing Record 45 of Set 10 | sadiqabad
# Processing Record 46 of Set 10 | tateyama
# Processing Record 47 of Set 10 | chlorakas
# Processing Record 48 of Set 10 | wattegama
# Processing Record 49 of Set 10 | menongue
# Processing Record 50 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 1 of Set 11 | syamzha
# Processing Record 2 of Set 11 | san rafael
# Processing Record 3 of Set 11 | natal
# Processing Record 4 of Set 11 | fenoarivo atsinanana
# Processing Record 5 of Set 11 | tirumullaivasal
# Processing Record 6 of Set 11 | byron bay
# Processing Record 7 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 11 | sri aman
# Processing Record 9 of Set 11 | ocos
# Processing Record 10 of Set 11 | nova olinda do norte
# Processing Record 11 of Set 11 | mumford
# Processing Record 12 of Set 11 | anadyr
# Processing Record 13 of Set 11 | zonguldak
# Processing Record 14 of Set 11 | eureka
# Processing Record 15 of Set 11 | porbandar
# Processing Record 16 of Set 11 | mehamn
# Processing Record 17 of Set 11 | naze
# Processing Record 18 of Set 11 | hasaki
# Processing Record 19 of Set 11 | santo andre
# Processing Record 20 of Set 11 | meulaboh
# Processing Record 21 of Set 11 | avera
# Processing Record 22 of Set 11 | cuauhtemoc
# Processing Record 23 of Set 11 | marstal
# Processing Record 24 of Set 11 | contamana
# Processing Record 25 of Set 11 | parsabad
# Processing Record 26 of Set 11 | khuzhir
# Processing Record 27 of Set 11 | nara
# Processing Record 28 of Set 11 | churapcha
# Processing Record 29 of Set 11 | winslow
# Processing Record 30 of Set 11 | brae
# Processing Record 31 of Set 11 | margate
# Processing Record 32 of Set 11 | ucluelet
# Processing Record 33 of Set 11 | thunder bay
# Processing Record 34 of Set 11 | taiyuan
# Processing Record 35 of Set 11 | kavaratti
# Processing Record 36 of Set 11 | dicabisagan
# Processing Record 37 of Set 11 | odweyne
# Processing Record 38 of Set 11 | pithora
# Processing Record 39 of Set 11 | nabire
# Processing Record 40 of Set 11 | sarkand
# Processing Record 41 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 11 | shaoyang
# Processing Record 43 of Set 11 | hammerfest
# Processing Record 44 of Set 11 | hervey bay
# Processing Record 45 of Set 11 | gazojak
# Processing Record 46 of Set 11 | ginir
# Processing Record 47 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 48 of Set 11 | yabrud
# Processing Record 49 of Set 11 | zanjan
# Processing Record 50 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | praxedis guerrero
# Processing Record 3 of Set 12 | quincy
# Processing Record 4 of Set 12 | nola
# Processing Record 5 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 6 of Set 12 | arona
# Processing Record 7 of Set 12 | bose
# Processing Record 8 of Set 12 | askiz
# Processing Record 9 of Set 12 | grindavik
# Processing Record 10 of Set 12 | puerto el triunfo
# Processing Record 11 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 12 | cuenca
# Processing Record 13 of Set 12 | mlimba
# Processing Record 14 of Set 12 | severomuysk
# Processing Record 15 of Set 12 | victorville
# Processing Record 16 of Set 12 | tecpan
# Processing Record 17 of Set 12 | miracema do tocantins
# Processing Record 18 of Set 12 | chiredzi
# Processing Record 19 of Set 12 | chor
# Processing Record 20 of Set 12 | bontang
# Processing Record 21 of Set 12 | warrington
# Processing Record 22 of Set 12 | iqaluit
# Processing Record 23 of Set 12 | bosaso
# Processing Record 24 of Set 12 | coari
# Processing Record 25 of Set 12 | tutoia
# Processing Record 26 of Set 12 | ascension
# Processing Record 27 of Set 12 | sisimiut
# Processing Record 28 of Set 12 | nouadhibou
# Processing Record 29 of Set 12 | correntina
# Processing Record 30 of Set 12 | katangli
# Processing Record 31 of Set 12 | yuci
# Processing Record 32 of Set 12 | rock sound
# Processing Record 33 of Set 12 | hami
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | santo domingo
# Processing Record 36 of Set 12 | sambava
# Processing Record 37 of Set 12 | tahe
# Processing Record 38 of Set 12 | nhulunbuy
# Processing Record 39 of Set 12 | tigzirt
# Processing Record 40 of Set 12 | lasa
# Processing Record 41 of Set 12 | morondava
# Processing Record 42 of Set 12 | ariquemes
# Processing Record 43 of Set 12 | codrington
# Processing Record 44 of Set 12 | alto araguaia
# Processing Record 45 of Set 12 | tortoli
# Processing Record 46 of Set 12 | cooma
# Processing Record 47 of Set 12 | mandan
# Processing Record 48 of Set 12 | bara
# Processing Record 49 of Set 12 | jurm
# Processing Record 50 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 13 | port hawkesbury
# Processing Record 2 of Set 13 | luanda
# Processing Record 3 of Set 13 | shangrao
# Processing Record 4 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 13 | koson
# Processing Record 6 of Set 13 | karla
# Processing Record 7 of Set 13 | shache
# Processing Record 8 of Set 13 | uri
# Processing Record 9 of Set 13 | entre rios
# Processing Record 10 of Set 13 | peyima
# Processing Record 11 of Set 13 | chicama
# Processing Record 12 of Set 13 | spearfish
# Processing Record 13 of Set 13 | warrenton
# Processing Record 14 of Set 13 | flinders
# Processing Record 15 of Set 13 | santa isabel do rio negro
# Processing Record 16 of Set 13 | birjand
# Processing Record 17 of Set 13 | aykhal
# Processing Record 18 of Set 13 | xinyang
# Processing Record 19 of Set 13 | batemans bay
# Processing Record 20 of Set 13 | kachug
# Processing Record 21 of Set 13 | narimanov
# Processing Record 22 of Set 13 | nurota
# Processing Record 23 of Set 13 | sa kaeo
# Processing Record 24 of Set 13 | log
# Processing Record 25 of Set 13 | atyrau
# Processing Record 26 of Set 13 | edd
# Processing Record 27 of Set 13 | murray bridge
# Processing Record 28 of Set 13 | marzuq
# Processing Record 29 of Set 13 | saldanha
# Processing Record 30 of Set 13 | namtsy
# Processing Record 31 of Set 13 | atasu
# Processing Record 32 of Set 13 | chernyy yar
# Processing Record 33 of Set 13 | limon
# Processing Record 34 of Set 13 | port victoria
# Processing Record 35 of Set 13 | ust-barguzin
# Processing Record 36 of Set 13 | mackay
# Processing Record 37 of Set 13 | dingle
# Processing Record 38 of Set 13 | klyuchi
# Processing Record 39 of Set 13 | the valley
# Processing Record 40 of Set 13 | mananjary
# Processing Record 41 of Set 13 | taltal
# Processing Record 42 of Set 13 | khandyga
# Processing Record 43 of Set 13 | aljezur
# Processing Record 44 of Set 13 | mount isa
# Processing Record 45 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 13 | metro
# Processing Record 47 of Set 13 | arraial do cabo
# Processing Record 48 of Set 13 | bundaberg
# Processing Record 49 of Set 13 | mae hong son
# Processing Record 50 of Set 13 | garowe
# Processing Record 1 of Set 14 | kushmurun
# Processing Record 2 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 14 | yenagoa
# Processing Record 4 of Set 14 | at-bashi
# Processing Record 5 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 14 | xuanzhou
# Processing Record 7 of Set 14 | angoche
# Processing Record 8 of Set 14 | nicoya
# Processing Record 9 of Set 14 | murwara
# Processing Record 10 of Set 14 | alcaniz
# Processing Record 11 of Set 14 | daugavpils
# Processing Record 12 of Set 14 | dawei
# Processing Record 13 of Set 14 | fereydun kenar
# Processing Record 14 of Set 14 | himora
# City not found. Skipping...
# Processing Record 15 of Set 14 | shelburne
# Processing Record 16 of Set 14 | litovko
# Processing Record 17 of Set 14 | basoko
# Processing Record 18 of Set 14 | katherine
# Processing Record 19 of Set 14 | vancouver
# Processing Record 20 of Set 14 | cape canaveral
# Processing Record 21 of Set 14 | sovetskaya gavan
# Processing Record 22 of Set 14 | gay
# Processing Record 23 of Set 14 | tabuk
# Processing Record 24 of Set 14 | darhan
# Processing Record 25 of Set 14 | carinhanha
# Processing Record 26 of Set 14 | tuatapere
# Processing Record 27 of Set 14 | gulmarg
# Processing Record 28 of Set 14 | montabaur
# Processing Record 29 of Set 14 | yen bai
# Processing Record 30 of Set 14 | tual
# Processing Record 31 of Set 14 | pochutla
# Processing Record 32 of Set 14 | balikpapan
# Processing Record 33 of Set 14 | selinia
# Processing Record 34 of Set 14 | bilibino
# Processing Record 35 of Set 14 | jati
# Processing Record 36 of Set 14 | albanel
# Processing Record 37 of Set 14 | kimbe
# Processing Record 38 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 39 of Set 14 | qasigiannguit
# Processing Record 40 of Set 14 | mednogorsk
# Processing Record 41 of Set 14 | whitecourt
# Processing Record 42 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 43 of Set 14 | uruzgan
# Processing Record 44 of Set 14 | candido de abreu
# Processing Record 45 of Set 14 | arlit
# Processing Record 46 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 47 of Set 14 | kerema
# Processing Record 48 of Set 14 | batagay-alyta
# Processing Record 49 of Set 14 | phalodi
# Processing Record 50 of Set 14 | quthing
# Processing Record 1 of Set 15 | kolomak
# Processing Record 2 of Set 15 | ondangwa
# Processing Record 3 of Set 15 | xinzhi
# Processing Record 4 of Set 15 | obluche
# City not found. Skipping...
# Processing Record 5 of Set 15 | manhattan
# Processing Record 6 of Set 15 | balaipungut
# Processing Record 7 of Set 15 | touros
# Processing Record 8 of Set 15 | mariental
# Processing Record 9 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 10 of Set 15 | ryotsu
# Processing Record 11 of Set 15 | thio
# Processing Record 12 of Set 15 | ludvika
# Processing Record 13 of Set 15 | empalme
# Processing Record 14 of Set 15 | nelson bay
# Processing Record 15 of Set 15 | erenhot
# Processing Record 16 of Set 15 | bud
# Processing Record 17 of Set 15 | shimoda
# Processing Record 18 of Set 15 | vila
# Processing Record 19 of Set 15 | creel
# Processing Record 20 of Set 15 | sao gabriel da cachoeira
# Processing Record 21 of Set 15 | knyaze-volkonskoye
# Processing Record 22 of Set 15 | ambovombe
# Processing Record 23 of Set 15 | gondanglegi
# Processing Record 24 of Set 15 | adre
# Processing Record 25 of Set 15 | mokhsogollokh
# Processing Record 26 of Set 15 | bograd
# Processing Record 27 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 15 | sargatskoye
# Processing Record 29 of Set 15 | jinchang
# Processing Record 30 of Set 15 | magan
# Processing Record 31 of Set 15 | wau
# Processing Record 32 of Set 15 | indramayu
# Processing Record 33 of Set 15 | xico
# Processing Record 34 of Set 15 | nikki
# Processing Record 35 of Set 15 | bramming
# Processing Record 36 of Set 15 | yerbogachen
# Processing Record 37 of Set 15 | alexandria
# Processing Record 38 of Set 15 | owando
# Processing Record 39 of Set 15 | sorland
# Processing Record 40 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 15 | kupang
# Processing Record 42 of Set 15 | rocha
# Processing Record 43 of Set 15 | balaguer
# Processing Record 44 of Set 15 | saint-pierre
# Processing Record 45 of Set 15 | jacksonville beach
# Processing Record 46 of Set 15 | eirunepe
# Processing Record 47 of Set 15 | sobolevo
# Processing Record 48 of Set 15 | parakou
# Processing Record 49 of Set 15 | lalmohan
# Processing Record 50 of Set 15 | kushima
# Processing Record 1 of Set 16 | milkovo
# Processing Record 2 of Set 16 | chengde
# Processing Record 3 of Set 16 | panuco
# Processing Record 4 of Set 16 | juba
# Processing Record 5 of Set 16 | porto recanati
# Processing Record 6 of Set 16 | tres arroyos
# Processing Record 7 of Set 16 | stadthagen
# Processing Record 8 of Set 16 | touba
# Processing Record 9 of Set 16 | paoua
# Processing Record 10 of Set 16 | port moresby
# Processing Record 11 of Set 16 | kamsack
# Processing Record 12 of Set 16 | port hedland
# Processing Record 13 of Set 16 | manjacaze
# Processing Record 14 of Set 16 | finschhafen
# Processing Record 15 of Set 16 | tra vinh
# Processing Record 16 of Set 16 | ust-nera
# Processing Record 17 of Set 16 | mareeba
# Processing Record 18 of Set 16 | yumen
# Processing Record 19 of Set 16 | bilaspur
# Processing Record 20 of Set 16 | deputatskiy
# Processing Record 21 of Set 16 | puerto maldonado
# Processing Record 22 of Set 16 | ciudad bolivar
# Processing Record 23 of Set 16 | las choapas
# Processing Record 24 of Set 16 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 16 | parabel
# Processing Record 26 of Set 16 | deep river
# Processing Record 27 of Set 16 | halol
# Processing Record 28 of Set 16 | alim
# Processing Record 29 of Set 16 | akdepe
# Processing Record 30 of Set 16 | moravska trebova
# Processing Record 31 of Set 16 | misratah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 721

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp Current Description  \
# 0            San Vicente -26.6167  -54.1333     78.76     overcast clouds
# 1                Astoria  46.1879 -123.8313     61.86       broken clouds
# 2             Bredasdorp -34.5322   20.0403     63.32       broken clouds
# 3        Puerto Ayacucho   5.6639  -67.6236     87.84       broken clouds
# 4  Imeni Poliny Osipenko  52.4201  136.4853     28.98    scattered clouds
# 5         Kulhudhuffushi   6.6221   73.0700     77.85     overcast clouds
# 6                Rikitea -23.1203 -134.9692     68.81       broken clouds
# 7               Svetlaya  46.5389  138.3297     37.74          few clouds
# 8                  Cervo  43.6702   -7.4101     64.49    scattered clouds
# 9                  Arawa  -6.2132  155.5367     76.48       broken clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        46         100        4.52      AR
# 1        92          84        1.99      US
# 2        87          64        7.67      ZA
# 3        60          74        3.56      VE
# 4        63          35        4.00      RU
# 5        90         100       18.84      MV
# 6        64          53       18.57      PF
# 7        65          22        8.01      RU
# 8        91          38        9.24      ES
# 9        92          77        1.79      PG

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df = new_column_order

# Display sample data
city_data_df.head()
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0            San Vicente      AR -26.6167  -54.1333     78.76        46
# 1                Astoria      US  46.1879 -123.8313     61.86        92
# 2             Bredasdorp      ZA -34.5322   20.0403     63.32        87
# 3        Puerto Ayacucho      VE   5.6639  -67.6236     87.84        60
# 4  Imeni Poliny Osipenko      RU  52.4201  136.4853     28.98        63
#
#    Cloudiness  Wind Speed Current Description
# 0         100        4.52     overcast clouds
# 1          84        1.99       broken clouds
# 2          64        7.67       broken clouds
# 3          74        3.56       broken clouds
# 4          35        4.00    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
