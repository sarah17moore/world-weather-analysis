# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for each city
city_url = url + "&q=" + city.replace(" ","+")

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port lincoln
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | viransehir
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | solnechnyy
# Processing Record 8 of Set 1 | pinsk
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | kimbe
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | port hardy
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | kysyl-syr
# Processing Record 15 of Set 1 | belushya guba
# Processing Record 16 of Set 1 | douglas
# Processing Record 17 of Set 1 | ancud
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | bafra
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | pevek
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | tazovskiy
# Processing Record 29 of Set 1 | turtas
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | portland
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | dondo
# Processing Record 36 of Set 1 | danielskuil
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | sete
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | illoqqortoormiut
# Processing Record 45 of Set 1 | salalah
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | lagoa
# Processing Record 48 of Set 1 | vostok
# Processing Record 49 of Set 1 | chapais
# Processing Record 50 of Set 1 | namibe
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | tumannyy
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | terre haute
# Processing Record 5 of Set 2 | scarborough
# Processing Record 6 of Set 2 | nizhneyansk
# Processing Record 7 of Set 2 | barentsburg
# Processing Record 8 of Set 2 | vardo
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | kousseri
# Processing Record 12 of Set 2 | krasnyy chikoy
# Processing Record 13 of Set 2 | macusani
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | dhadar
# Processing Record 16 of Set 2 | jacqueville
# Processing Record 17 of Set 2 | zapadnaya dvina
# Processing Record 18 of Set 2 | guamal
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | oranjestad
# Processing Record 21 of Set 2 | beclean
# Processing Record 22 of Set 2 | belaya gora
# Processing Record 23 of Set 2 | senno
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | great yarmouth
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | udachnyy
# Processing Record 31 of Set 2 | elban
# Processing Record 32 of Set 2 | banda aceh
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | kiama
# Processing Record 35 of Set 2 | batemans bay
# Processing Record 36 of Set 2 | tsihombe
# Processing Record 37 of Set 2 | hovd
# Processing Record 38 of Set 2 | ambilobe
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | kaeo
# Processing Record 42 of Set 2 | hambantota
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | taolanaro
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | aksarayskiy
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | aboso
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | stornoway
# Processing Record 1 of Set 3 | leningradskiy
# Processing Record 2 of Set 3 | zhigansk
# Processing Record 3 of Set 3 | boende
# Processing Record 4 of Set 3 | alta floresta
# Processing Record 5 of Set 3 | kibala
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | saint-denis
# Processing Record 8 of Set 3 | nur
# Processing Record 9 of Set 3 | nanortalik
# Processing Record 10 of Set 3 | nioro
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | kampene
# Processing Record 15 of Set 3 | albany
# Processing Record 16 of Set 3 | gainesville
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | guerrero negro
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | adiake
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | najran
# Processing Record 24 of Set 3 | molina
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | gizo
# Processing Record 27 of Set 3 | saint-augustin
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | mineros
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | acapulco
# Processing Record 32 of Set 3 | sorland
# Processing Record 33 of Set 3 | ibiuna
# Processing Record 34 of Set 3 | akyab
# Processing Record 35 of Set 3 | nueve de julio
# Processing Record 36 of Set 3 | inhambane
# Processing Record 37 of Set 3 | padang
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | mys shmidta
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | sao felix do xingu
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | falam
# Processing Record 44 of Set 3 | ponerihouen
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | savannah bight
# Processing Record 48 of Set 3 | kabompo
# Processing Record 49 of Set 3 | santander
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | santo antonio do leverger
# Processing Record 2 of Set 4 | mancio lima
# Processing Record 3 of Set 4 | port keats
# Processing Record 4 of Set 4 | kindersley
# Processing Record 5 of Set 4 | jasper
# Processing Record 6 of Set 4 | harmanli
# Processing Record 7 of Set 4 | saskylakh
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | opuwo
# Processing Record 10 of Set 4 | yatou
# Processing Record 11 of Set 4 | tashla
# Processing Record 12 of Set 4 | roma
# Processing Record 13 of Set 4 | nanakuli
# Processing Record 14 of Set 4 | sapernoye
# Processing Record 15 of Set 4 | zunheboto
# Processing Record 16 of Set 4 | mpongwe
# Processing Record 17 of Set 4 | soyo
# Processing Record 18 of Set 4 | alekseyevka
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | ostrovnoy
# Processing Record 21 of Set 4 | coquimbo
# Processing Record 22 of Set 4 | bilibino
# Processing Record 23 of Set 4 | atoyac
# Processing Record 24 of Set 4 | kristiansund
# Processing Record 25 of Set 4 | smithers
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | francia
# Processing Record 28 of Set 4 | thunder bay
# Processing Record 29 of Set 4 | cabra
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | bandarbeyla
# Processing Record 32 of Set 4 | amderma
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | ola
# Processing Record 36 of Set 4 | rambouillet
# Processing Record 37 of Set 4 | mpulungu
# Processing Record 38 of Set 4 | save
# Processing Record 39 of Set 4 | esmeraldas
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | grindavik
# Processing Record 42 of Set 4 | nouadhibou
# Processing Record 43 of Set 4 | sioux lookout
# Processing Record 44 of Set 4 | sambava
# Processing Record 45 of Set 4 | itoman
# Processing Record 46 of Set 4 | barawe
# Processing Record 47 of Set 4 | baraboo
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | ulaanbaatar
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | dawei
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | colac
# Processing Record 4 of Set 5 | gladstone
# Processing Record 5 of Set 5 | severo-kurilsk
# Processing Record 6 of Set 5 | chumikan
# Processing Record 7 of Set 5 | juba
# Processing Record 8 of Set 5 | vaitupu
# Processing Record 9 of Set 5 | durant
# Processing Record 10 of Set 5 | arraial do cabo
# Processing Record 11 of Set 5 | saa
# Processing Record 12 of Set 5 | rongcheng
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | tahta
# Processing Record 15 of Set 5 | nishihara
# Processing Record 16 of Set 5 | katangli
# Processing Record 17 of Set 5 | tiarei
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | nicoya
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | maningrida
# Processing Record 23 of Set 5 | bargal
# Processing Record 24 of Set 5 | lolua
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | becerril
# Processing Record 27 of Set 5 | epinay-sur-orge
# Processing Record 28 of Set 5 | omsukchan
# Processing Record 29 of Set 5 | pestravka
# Processing Record 30 of Set 5 | praya
# Processing Record 31 of Set 5 | te anau
# Processing Record 32 of Set 5 | neuquen
# Processing Record 33 of Set 5 | konstantinovo
# Processing Record 34 of Set 5 | kieta
# Processing Record 35 of Set 5 | kaili
# Processing Record 36 of Set 5 | aklavik
# Processing Record 37 of Set 5 | barranca
# Processing Record 38 of Set 5 | attawapiskat
# Processing Record 39 of Set 5 | shu
# Processing Record 40 of Set 5 | birsk
# Processing Record 41 of Set 5 | lamu
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | at-bashi
# Processing Record 44 of Set 5 | prince rupert
# Processing Record 45 of Set 5 | jiuquan
# Processing Record 46 of Set 5 | sentyabrskiy
# Processing Record 47 of Set 5 | pestovo
# Processing Record 48 of Set 5 | rawson
# Processing Record 49 of Set 5 | mecca
# Processing Record 50 of Set 5 | provideniya
# Processing Record 1 of Set 6 | dobele
# Processing Record 2 of Set 6 | riohacha
# Processing Record 3 of Set 6 | tutoia
# Processing Record 4 of Set 6 | ampanihy
# Processing Record 5 of Set 6 | poniatowa
# Processing Record 6 of Set 6 | weslaco
# Processing Record 7 of Set 6 | lorengau
# Processing Record 8 of Set 6 | bur gabo
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | newport
# Processing Record 11 of Set 6 | husavik
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | tornio
# Processing Record 15 of Set 6 | pangnirtung
# Processing Record 16 of Set 6 | san cristobal
# Processing Record 17 of Set 6 | boden
# Processing Record 18 of Set 6 | tir pol
# Processing Record 19 of Set 6 | ketchikan
# Processing Record 20 of Set 6 | urucara
# Processing Record 21 of Set 6 | marawi
# Processing Record 22 of Set 6 | mumford
# Processing Record 23 of Set 6 | adrar
# Processing Record 24 of Set 6 | chalon-sur-saone
# Processing Record 25 of Set 6 | umzimvubu
# Processing Record 26 of Set 6 | moose factory
# Processing Record 27 of Set 6 | mahebourg
# Processing Record 28 of Set 6 | katherine
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | ahipara
# Processing Record 31 of Set 6 | pacific grove
# Processing Record 32 of Set 6 | viligili
# Processing Record 33 of Set 6 | sistranda
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | weligama
# Processing Record 36 of Set 6 | turukhansk
# Processing Record 37 of Set 6 | grand river south east
# Processing Record 38 of Set 6 | conde
# Processing Record 39 of Set 6 | killybegs
# Processing Record 40 of Set 6 | kaoma
# Processing Record 41 of Set 6 | natal
# Processing Record 42 of Set 6 | narrabri
# Processing Record 43 of Set 6 | poronaysk
# Processing Record 44 of Set 6 | wanaka
# Processing Record 45 of Set 6 | mashhad
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | angoche
# Processing Record 48 of Set 6 | grajau
# Processing Record 49 of Set 6 | clyde river
# Processing Record 50 of Set 6 | samusu
# Processing Record 1 of Set 7 | buraydah
# Processing Record 2 of Set 7 | bentiu
# Processing Record 3 of Set 7 | ca mau
# Processing Record 4 of Set 7 | dunedin
# Processing Record 5 of Set 7 | fort saint james
# Processing Record 6 of Set 7 | ojinaga
# Processing Record 7 of Set 7 | middelkerke
# Processing Record 8 of Set 7 | samarai
# Processing Record 9 of Set 7 | ciamis
# Processing Record 10 of Set 7 | bethanien
# Processing Record 11 of Set 7 | malwan
# Processing Record 12 of Set 7 | sukumo
# Processing Record 13 of Set 7 | kruisfontein
# Processing Record 14 of Set 7 | fort saint john
# Processing Record 15 of Set 7 | rocha
# Processing Record 16 of Set 7 | nipawin
# Processing Record 17 of Set 7 | mosetse
# Processing Record 18 of Set 7 | viedma
# Processing Record 19 of Set 7 | bosaso
# Processing Record 20 of Set 7 | bulgan
# Processing Record 21 of Set 7 | harper
# Processing Record 22 of Set 7 | the valley
# Processing Record 23 of Set 7 | letterkenny
# Processing Record 24 of Set 7 | calbuco
# Processing Record 25 of Set 7 | yulara
# Processing Record 26 of Set 7 | neepawa
# Processing Record 27 of Set 7 | mackenzie
# Processing Record 28 of Set 7 | le port
# Processing Record 29 of Set 7 | khatanga
# Processing Record 30 of Set 7 | longyearbyen
# Processing Record 31 of Set 7 | marmaron
# Processing Record 32 of Set 7 | nuuk
# Processing Record 33 of Set 7 | vila franca do campo
# Processing Record 34 of Set 7 | kaitangata
# Processing Record 35 of Set 7 | skelleftea
# Processing Record 36 of Set 7 | merrill
# Processing Record 37 of Set 7 | mudgee
# Processing Record 38 of Set 7 | ailigandi
# Processing Record 39 of Set 7 | nosy varika
# Processing Record 40 of Set 7 | kamien pomorski
# Processing Record 41 of Set 7 | kungsbacka
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | skibbereen
# Processing Record 44 of Set 7 | port-gentil
# Processing Record 45 of Set 7 | suntar
# Processing Record 46 of Set 7 | oksfjord
# Processing Record 47 of Set 7 | virginia beach
# Processing Record 48 of Set 7 | shubarkuduk
# Processing Record 49 of Set 7 | dudinka
# Processing Record 50 of Set 7 | broken hill
# Processing Record 1 of Set 8 | berlevag
# Processing Record 2 of Set 8 | bubaque
# Processing Record 3 of Set 8 | baruun-urt
# Processing Record 4 of Set 8 | bagepalli
# Processing Record 5 of Set 8 | san patricio
# Processing Record 6 of Set 8 | pozo colorado
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | dhing
# Processing Record 9 of Set 8 | hachinohe
# Processing Record 10 of Set 8 | gao
# Processing Record 11 of Set 8 | burnie
# Processing Record 12 of Set 8 | port antonio
# Processing Record 13 of Set 8 | karakol
# Processing Record 14 of Set 8 | garm
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | geraldton
# Processing Record 17 of Set 8 | assela
# Processing Record 18 of Set 8 | neiafu
# Processing Record 19 of Set 8 | oakdale
# Processing Record 20 of Set 8 | bay roberts
# Processing Record 21 of Set 8 | altay
# Processing Record 22 of Set 8 | paraiso
# Processing Record 23 of Set 8 | louisbourg
# Processing Record 24 of Set 8 | malanje
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | komsomolskiy
# Processing Record 27 of Set 8 | northam
# Processing Record 28 of Set 8 | puerto castilla
# Processing Record 29 of Set 8 | moshupa
# Processing Record 30 of Set 8 | sao mateus
# Processing Record 31 of Set 8 | flin flon
# Processing Record 32 of Set 8 | naze
# Processing Record 33 of Set 8 | krasnomayskiy
# Processing Record 34 of Set 8 | sao jose da coroa grande
# Processing Record 35 of Set 8 | sangar
# Processing Record 36 of Set 8 | villa union
# Processing Record 37 of Set 8 | merauke
# Processing Record 38 of Set 8 | kenitra
# Processing Record 39 of Set 8 | lipin bor
# Processing Record 40 of Set 8 | jalu
# Processing Record 41 of Set 8 | tarudant
# Processing Record 42 of Set 8 | pitimbu
# Processing Record 43 of Set 8 | kargil
# Processing Record 44 of Set 8 | mahajanga
# Processing Record 45 of Set 8 | kapchorwa
# Processing Record 46 of Set 8 | henties bay
# Processing Record 47 of Set 8 | avera
# Processing Record 48 of Set 8 | taylor
# Processing Record 49 of Set 8 | sisimiut
# Processing Record 50 of Set 8 | morondava
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | svetlogorsk
# Processing Record 3 of Set 9 | havoysund
# Processing Record 4 of Set 9 | houston
# Processing Record 5 of Set 9 | souillac
# Processing Record 6 of Set 9 | touros
# Processing Record 7 of Set 9 | kirksville
# Processing Record 8 of Set 9 | fortuna
# Processing Record 9 of Set 9 | bereda
# Processing Record 10 of Set 9 | dingle
# Processing Record 11 of Set 9 | huicheng
# Processing Record 12 of Set 9 | tura
# Processing Record 13 of Set 9 | ust-nera
# Processing Record 14 of Set 9 | bonavista
# Processing Record 15 of Set 9 | riyadh
# Processing Record 16 of Set 9 | bathsheba
# Processing Record 17 of Set 9 | eyl
# Processing Record 18 of Set 9 | umba
# Processing Record 19 of Set 9 | deputatskiy
# Processing Record 20 of Set 9 | seymchan
# Processing Record 21 of Set 9 | kasongo-lunda
# Processing Record 22 of Set 9 | saint-michel-des-saints
# Processing Record 23 of Set 9 | sinnamary
# Processing Record 24 of Set 9 | yurimaguas
# Processing Record 25 of Set 9 | balikpapan
# Processing Record 26 of Set 9 | waipawa
# Processing Record 27 of Set 9 | batagay-alyta
# Processing Record 28 of Set 9 | tilichiki
# Processing Record 29 of Set 9 | nassau
# Processing Record 30 of Set 9 | jega
# Processing Record 31 of Set 9 | ushibuka
# Processing Record 32 of Set 9 | manzhouli
# Processing Record 33 of Set 9 | bacuit
# Processing Record 34 of Set 9 | farafangana
# Processing Record 35 of Set 9 | thinadhoo
# Processing Record 36 of Set 9 | tarko-sale
# Processing Record 37 of Set 9 | bahia blanca
# Processing Record 38 of Set 9 | ixtapa
# Processing Record 39 of Set 9 | victoria point
# Processing Record 40 of Set 9 | katha
# Processing Record 41 of Set 9 | valparaiso
# Processing Record 42 of Set 9 | cururupu
# Processing Record 43 of Set 9 | makokou
# Processing Record 44 of Set 9 | misratah
# Processing Record 45 of Set 9 | kloulklubed
# Processing Record 46 of Set 9 | goderich
# Processing Record 47 of Set 9 | marcona
# Processing Record 48 of Set 9 | hue
# Processing Record 49 of Set 9 | macaboboni
# Processing Record 50 of Set 9 | muisne
# Processing Record 1 of Set 10 | san juan de los morros
# Processing Record 2 of Set 10 | westpunt
# Processing Record 3 of Set 10 | pak phanang
# Processing Record 4 of Set 10 | tansen
# Processing Record 5 of Set 10 | kitimat
# Processing Record 6 of Set 10 | muros
# Processing Record 7 of Set 10 | lagunas
# Processing Record 8 of Set 10 | puerto leguizamo
# Processing Record 9 of Set 10 | zelenets
# Processing Record 10 of Set 10 | kabo
# Processing Record 11 of Set 10 | sofiysk
# Processing Record 12 of Set 10 | cayenne
# Processing Record 13 of Set 10 | codrington
# Processing Record 14 of Set 10 | ranong
# Processing Record 15 of Set 10 | olot
# Processing Record 16 of Set 10 | micheweni
# Processing Record 17 of Set 10 | bethel
# Processing Record 18 of Set 10 | asfi
# Processing Record 19 of Set 10 | coihaique
# Processing Record 20 of Set 10 | kholmogory
# Processing Record 21 of Set 10 | markova
# Processing Record 22 of Set 10 | tromso
# Processing Record 23 of Set 10 | constantine
# Processing Record 24 of Set 10 | clinton
# Processing Record 25 of Set 10 | richards bay
# Processing Record 26 of Set 10 | tabou
# Processing Record 27 of Set 10 | sorvag
# Processing Record 28 of Set 10 | quatre cocos
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | sao paulo de olivenca
# Processing Record 31 of Set 10 | galle
# Processing Record 32 of Set 10 | guiratinga
# Processing Record 33 of Set 10 | walvis bay
# Processing Record 34 of Set 10 | caravelas
# Processing Record 35 of Set 10 | krasnoarmeysk
# Processing Record 36 of Set 10 | hay river
# Processing Record 37 of Set 10 | teahupoo
# Processing Record 38 of Set 10 | oriximina
# Processing Record 39 of Set 10 | kerava
# Processing Record 40 of Set 10 | aste
# Processing Record 41 of Set 10 | spirit river
# Processing Record 42 of Set 10 | verkhoyansk
# Processing Record 43 of Set 10 | bhagalpur
# Processing Record 44 of Set 10 | buon me thuot
# Processing Record 45 of Set 10 | teya
# Processing Record 46 of Set 10 | ji-parana
# Processing Record 47 of Set 10 | san ramon
# Processing Record 48 of Set 10 | bom jesus do itabapoana
# Processing Record 49 of Set 10 | ipixuna
# Processing Record 50 of Set 10 | alexandria
# Processing Record 1 of Set 11 | bainbridge
# Processing Record 2 of Set 11 | chara
# Processing Record 3 of Set 11 | doka
# Processing Record 4 of Set 11 | muravlenko
# Processing Record 5 of Set 11 | vung tau
# Processing Record 6 of Set 11 | kuche
# Processing Record 7 of Set 11 | inderborskiy
# Processing Record 8 of Set 11 | lanxi
# Processing Record 9 of Set 11 | gunnedah
# Processing Record 10 of Set 11 | pemangkat
# Processing Record 11 of Set 11 | lahij
# Processing Record 12 of Set 11 | murray bridge
# Processing Record 13 of Set 11 | superior
# Processing Record 14 of Set 11 | monterey
# Processing Record 15 of Set 11 | pleasanton
# Processing Record 16 of Set 11 | klaksvik
# Processing Record 17 of Set 11 | oranjemund
# Processing Record 18 of Set 11 | brae
# Processing Record 19 of Set 11 | lorsch
# Processing Record 20 of Set 11 | katobu
# Processing Record 21 of Set 11 | mandera
# Processing Record 22 of Set 11 | rengo
# Processing Record 23 of Set 11 | nhulunbuy
# Processing Record 24 of Set 11 | broome
# Processing Record 25 of Set 11 | hargeysa
# Processing Record 26 of Set 11 | roura
# Processing Record 27 of Set 11 | palabuhanratu
# Processing Record 28 of Set 11 | gaspe
# Processing Record 29 of Set 11 | lavrentiya
# Processing Record 30 of Set 11 | cape girardeau
# Processing Record 31 of Set 11 | svetlaya
# Processing Record 32 of Set 11 | strezhevoy
# Processing Record 33 of Set 11 | kiunga
# Processing Record 34 of Set 11 | saleaula
# Processing Record 35 of Set 11 | iquique
# Processing Record 36 of Set 11 | raikot
# Processing Record 37 of Set 11 | aurora
# Processing Record 38 of Set 11 | panguna
# Processing Record 39 of Set 11 | mahibadhoo
# Processing Record 40 of Set 11 | makurdi
# Processing Record 41 of Set 11 | jardim
# Processing Record 42 of Set 11 | vila
# Processing Record 43 of Set 11 | tubmanburg
# Processing Record 44 of Set 11 | kurilsk
# Processing Record 45 of Set 11 | cazaje
# Processing Record 46 of Set 11 | quesnel
# Processing Record 47 of Set 11 | ohafia
# Processing Record 48 of Set 11 | ryotsu
# Processing Record 49 of Set 11 | bukoba
# Processing Record 50 of Set 11 | takoradi
# Processing Record 1 of Set 12 | whitehorse
# Processing Record 2 of Set 12 | san policarpo
# Processing Record 3 of Set 12 | okhotsk
# Processing Record 4 of Set 12 | starotitarovskaya
# Processing Record 5 of Set 12 | gannan
# Processing Record 6 of Set 12 | umm lajj
# Processing Record 7 of Set 12 | makakilo city
# Processing Record 8 of Set 12 | linxia
# Processing Record 9 of Set 12 | tamandare
# Processing Record 10 of Set 12 | zunyi
# Processing Record 11 of Set 12 | saint-pierre
# Processing Record 12 of Set 12 | tuatapere
# Processing Record 13 of Set 12 | seoul
# Processing Record 14 of Set 12 | lichtenburg
# Processing Record 15 of Set 12 | penzance
# Processing Record 16 of Set 12 | walla walla
# Processing Record 17 of Set 12 | axim
# Processing Record 18 of Set 12 | baijiantan
# Processing Record 19 of Set 12 | faya
# Processing Record 20 of Set 12 | kralendijk
# Processing Record 21 of Set 12 | aswan
# Processing Record 22 of Set 12 | tigzirt
# Processing Record 23 of Set 12 | lasa
# Processing Record 24 of Set 12 | chokurdakh
# Processing Record 25 of Set 12 | south venice
# Processing Record 26 of Set 12 | debre tabor
# Processing Record 27 of Set 12 | ayorou
# Processing Record 28 of Set 12 | varhaug
# Processing Record 29 of Set 12 | general roca
# Processing Record 30 of Set 12 | angicos
# Processing Record 31 of Set 12 | kuybysheve
# Processing Record 32 of Set 12 | kargopol
# Processing Record 33 of Set 12 | roald
# Processing Record 34 of Set 12 | abilene
# Processing Record 35 of Set 12 | high level
# Processing Record 36 of Set 12 | antalaha
# Processing Record 37 of Set 12 | ucluelet
# Processing Record 38 of Set 12 | laurel
# Processing Record 39 of Set 12 | flinders
# Processing Record 40 of Set 12 | samana
# Processing Record 41 of Set 12 | dori
# Processing Record 42 of Set 12 | carlagan
# Processing Record 43 of Set 12 | qena
# Processing Record 44 of Set 12 | bouca
# Processing Record 45 of Set 12 | evanston
# Processing Record 46 of Set 12 | jashpurnagar
# Processing Record 47 of Set 12 | baherden
# Processing Record 48 of Set 12 | tawkar
# Processing Record 49 of Set 12 | gumia
# Processing Record 50 of Set 12 | hirara
# Processing Record 1 of Set 13 | emerald
# Processing Record 2 of Set 13 | nelson bay
# Processing Record 3 of Set 13 | mehamn
# Processing Record 4 of Set 13 | buala
# Processing Record 5 of Set 13 | port hedland
# Processing Record 6 of Set 13 | biak
# Processing Record 7 of Set 13 | breytovo
# Processing Record 8 of Set 13 | neryungri
# Processing Record 9 of Set 13 | byron bay
# Processing Record 10 of Set 13 | pangody
# Processing Record 11 of Set 13 | pisco
# Processing Record 12 of Set 13 | egvekinot
# Processing Record 13 of Set 13 | nome
# Processing Record 14 of Set 13 | santa maria del oro
# Processing Record 15 of Set 13 | morant bay
# Processing Record 16 of Set 13 | tual
# Processing Record 17 of Set 13 | ozernovskiy
# Processing Record 18 of Set 13 | zhuhai
# Processing Record 19 of Set 13 | achisay
# Processing Record 20 of Set 13 | cravo norte
# Processing Record 21 of Set 13 | topolobampo
# Processing Record 22 of Set 13 | buta
# Processing Record 23 of Set 13 | gambela
# Processing Record 24 of Set 13 | cassilandia
# Processing Record 25 of Set 13 | roebourne
# Processing Record 26 of Set 13 | gengenbach
# Processing Record 27 of Set 13 | agboville
# Processing Record 28 of Set 13 | ahuimanu
# Processing Record 29 of Set 13 | mayo
# Processing Record 30 of Set 13 | santana do matos
# Processing Record 31 of Set 13 | burica
# Processing Record 32 of Set 13 | nicolas bravo
# Processing Record 33 of Set 13 | champasak
# Processing Record 34 of Set 13 | victor harbor
# Processing Record 35 of Set 13 | kdyne
# Processing Record 36 of Set 13 | tukrah
# Processing Record 37 of Set 13 | sabha
# Processing Record 38 of Set 13 | tucuma
# Processing Record 39 of Set 13 | ajmer
# Processing Record 40 of Set 13 | sataua
# Processing Record 41 of Set 13 | hede
# Processing Record 42 of Set 13 | iranshahr
# Processing Record 43 of Set 13 | isiro
# Processing Record 44 of Set 13 | palmer
# Processing Record 45 of Set 13 | ballstad
# Processing Record 46 of Set 13 | yenagoa
# Processing Record 47 of Set 13 | boyolangu
# Processing Record 48 of Set 13 | amiens
# Processing Record 49 of Set 13 | halalo
# Processing Record 50 of Set 13 | marzuq
# Processing Record 1 of Set 14 | limoges
# Processing Record 2 of Set 14 | vysokogornyy
# Processing Record 3 of Set 14 | sansai
# Processing Record 4 of Set 14 | asvanyraro
# Processing Record 5 of Set 14 | plaeng yao
# Processing Record 6 of Set 14 | kaeng khlo
# Processing Record 7 of Set 14 | pandamatenga
# Processing Record 8 of Set 14 | iquitos
# Processing Record 9 of Set 14 | kamenskoye
# Processing Record 10 of Set 14 | sumbe
# Processing Record 11 of Set 14 | honggang
# Processing Record 12 of Set 14 | kologriv
# Processing Record 13 of Set 14 | atambua
# Processing Record 14 of Set 14 | ramon castilla
# Processing Record 15 of Set 14 | zhanatas
# Processing Record 16 of Set 14 | sungai pelek
# Processing Record 17 of Set 14 | kirakira
# Processing Record 18 of Set 14 | saint-joseph
# Processing Record 19 of Set 14 | lotofaga
# Processing Record 20 of Set 14 | qasigiannguit
# Processing Record 21 of Set 14 | vryburg
# Processing Record 22 of Set 14 | cockburn town
# Processing Record 23 of Set 14 | ust-kamchatsk
# Processing Record 24 of Set 14 | pouembout
# Processing Record 25 of Set 14 | karratha
# Processing Record 26 of Set 14 | korla
# Processing Record 27 of Set 14 | hays
# Processing Record 28 of Set 14 | brufut
# Processing Record 29 of Set 14 | santa maria
# Processing Record 30 of Set 14 | asau
# Processing Record 31 of Set 14 | gonen
# Processing Record 32 of Set 14 | valkeala
# Processing Record 33 of Set 14 | dunmore town
# Processing Record 34 of Set 14 | isangel
# Processing Record 35 of Set 14 | toro
# Processing Record 36 of Set 14 | gotsu
# Processing Record 37 of Set 14 | innisfail
# Processing Record 38 of Set 14 | plettenberg bay
# Processing Record 39 of Set 14 | palu
# Processing Record 40 of Set 14 | hofn
# Processing Record 41 of Set 14 | bargarh
# Processing Record 42 of Set 14 | huarmey
# Processing Record 43 of Set 14 | rungata
# Processing Record 44 of Set 14 | talcahuano
# Processing Record 45 of Set 14 | wajima
# Processing Record 46 of Set 14 | guozhen
# Processing Record 47 of Set 14 | santa
# Processing Record 48 of Set 14 | abha
# Processing Record 49 of Set 14 | stilfontein
# Processing Record 50 of Set 14 | yerbogachen
# Processing Record 1 of Set 15 | hetauda
# Processing Record 2 of Set 15 | camacha
# Processing Record 3 of Set 15 | imbituba
# Processing Record 4 of Set 15 | diebougou
# Processing Record 5 of Set 15 | pangai
# Processing Record 6 of Set 15 | oktyabrskiy
# Processing Record 7 of Set 15 | barcelona
# Processing Record 8 of Set 15 | christiana
# Processing Record 9 of Set 15 | bilma
# Processing Record 10 of Set 15 | minab
# Processing Record 11 of Set 15 | prenzlau
# Processing Record 12 of Set 15 | new plymouth
# Processing Record 13 of Set 15 | acarau
# Processing Record 14 of Set 15 | wanning
# Processing Record 15 of Set 15 | moerai
# Processing Record 16 of Set 15 | bakchar
# Processing Record 17 of Set 15 | artvin
# Processing Record 18 of Set 15 | shadegan
# Processing Record 19 of Set 15 | shilka
# Processing Record 20 of Set 15 | vastervik
# Processing Record 21 of Set 15 | shihezi
# Processing Record 22 of Set 15 | charters towers
# Processing Record 23 of Set 15 | kamina
# Processing Record 24 of Set 15 | khani
# Processing Record 25 of Set 15 | chinsali
# Processing Record 26 of Set 15 | formoso do araguaia
# Processing Record 27 of Set 15 | diffa
# Processing Record 28 of Set 15 | khasan
# Processing Record 29 of Set 15 | balclutha
# Processing Record 30 of Set 15 | dongli
# Processing Record 31 of Set 15 | taoudenni
# Processing Record 32 of Set 15 | meyungs
# Processing Record 33 of Set 15 | kolokani
# Processing Record 34 of Set 15 | noyabrsk
# Processing Record 35 of Set 15 | rize
# Processing Record 36 of Set 15 | tiznit
# Processing Record 37 of Set 15 | xining
# Processing Record 38 of Set 15 | tatarsk
# Processing Record 39 of Set 15 | sakakah
# Processing Record 40 of Set 15 | shimanovsk
# Processing Record 41 of Set 15 | betafo
# Processing Record 42 of Set 15 | shar
# Processing Record 43 of Set 15 | teguldet
# Processing Record 44 of Set 15 | half moon bay
# Processing Record 45 of Set 15 | gorom-gorom
# Processing Record 46 of Set 15 | evensk
# Processing Record 47 of Set 15 | cabedelo
# Processing Record 48 of Set 15 | parabel
# Processing Record 49 of Set 15 | svetlyy
# Processing Record 50 of Set 15 | zhanaozen
# Processing Record 1 of Set 16 | tayshet
# Processing Record 2 of Set 16 | one hundred mile house
# Processing Record 3 of Set 16 | ottumwa
# Processing Record 4 of Set 16 | odienne
# Processing Record 5 of Set 16 | aitape
# Processing Record 6 of Set 16 | kokkola
# Processing Record 7 of Set 16 | mullaitivu
# Processing Record 8 of Set 16 | gayeri
# Processing Record 9 of Set 16 | santa barbara
# Processing Record 10 of Set 16 | sechura
# Processing Record 11 of Set 16 | ayan
# Processing Record 12 of Set 16 | young
# Processing Record 13 of Set 16 | astana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 763

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat     Lng  Max Temp Current Description  Humidity  \
# 0  Port Lincoln  51.1801  71.446     33.75           clear sky        75
# 1    Georgetown  51.1801  71.446     33.75           clear sky        75
# 2    Viransehir  51.1801  71.446     33.75           clear sky        75
# 3    Bredasdorp  51.1801  71.446     33.75           clear sky        75
# 4      Thompson  51.1801  71.446     33.75           clear sky        75
# 5       Qaanaaq  51.1801  71.446     33.75           clear sky        75
# 6    Solnechnyy  51.1801  71.446     33.75           clear sky        75
# 7         Pinsk  51.1801  71.446     33.75           clear sky        75
# 8     Cape Town  51.1801  71.446     33.75           clear sky        75
# 9         Kimbe  51.1801  71.446     33.75           clear sky        75
#
#    Cloudiness  Wind Speed Country
# 0           0        8.95      KZ
# 1           0        8.95      KZ
# 2           0        8.95      KZ
# 3           0        8.95      KZ
# 4           0        8.95      KZ
# 5           0        8.95      KZ
# 6           0        8.95      KZ
# 7           0        8.95      KZ
# 8           0        8.95      KZ
# 9           0        8.95      KZ

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df = new_column_order

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Lincoln      KZ  51.1801  71.446     33.75        75           0
# 1    Georgetown      KZ  51.1801  71.446     33.75        75           0
# 2    Viransehir      KZ  51.1801  71.446     33.75        75           0
# 3    Bredasdorp      KZ  51.1801  71.446     33.75        75           0
# 4      Thompson      KZ  51.1801  71.446     33.75        75           0
#
#    Wind Speed Current Description
# 0        8.95           clear sky
# 1        8.95           clear sky
# 2        8.95           clear sky
# 3        8.95           clear sky
# 4        8.95           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
